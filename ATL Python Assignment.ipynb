# %% [markdown]
# # ATL Python Assignment

# %% [markdown]
# ## Study and perform Data Analytics and Data Visualization using Numpy, Pandas and Matplotlib

# %% [markdown]
# ### 1. Write a Python program to display first 5 rows from COVID-19 dataset. Also print the dataset information and check the missing

# %%
# Import pandas

import pandas as pd

# %%
# Read COVID 19 Dataset CSV File using pandas
df = pd.read_csv('covid_19_data.csv')

# Print File Data 
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
# Print First Five Rows
df[:5]
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
# Print Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  object
#  2   Province/State   228329 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  object
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 18.7+ MB

# %%
# Print Missing Values
df.isna().sum()
# Out:
# SNo                    0
# ObservationDate        0
# Province/State     78100
# Country/Region         0
# Last Update            0
# Confirmed              0
# Deaths                 0
# Recovered              0
# dtype: int64

# %% [markdown]
# ### 2. Write a Python program to get the latest number of confirmed, deaths, recovered and active cases of Novel Coronavirus (COVID-19) Country wise.

# %%
# Import pandas

import pandas as pd

# %%
# Read COVID 19 Dataset CSV File using pandas
df = pd.read_csv('covid_19_data.csv')

# Print File Data 
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
# Active Cases Calculate 
df['Active'] = df['Confirmed'] - df['Deaths'] - df['Recovered']

df['Active']
# Out:
# 0              1.0
# 1             14.0
# 2              6.0
# 3              1.0
# 4              0.0
#             ...
# 306424      5017.0
# 306425     28902.0
# 306426        39.0
# 306427      2022.0
# 306428    387307.0
# Name: Active, Length: 306429, dtype: float64

# %%
# Print latest number of confirmed, deaths, recovered and active cases of Novel Coronavirus (COVID-19) Country wise
g = df.groupby('Country/Region')['Confirmed', 'Deaths','Recovered','Active'].sum().reset_index()

g
# Out:
# <ipython-input-38-5b126d0ace48>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   g = df.groupby('Country/Region')['Confirmed', 'Deaths','Recovered','Active'].sum().reset_index()
#                      Country/Region   Confirmed    Deaths   Recovered  \
# 0                        Azerbaijan         1.0       0.0         0.0
# 1                   ('St. Martin',)         2.0       0.0         0.0
# 2                       Afghanistan  17026442.0  669075.0  13464399.0
# 3                           Albania  19768869.0  375955.0  13945256.0
# 4                           Algeria  27684358.0  834464.0  18959299.0
# ..                              ...         ...       ...         ...
# 224              West Bank and Gaza  41819444.0  440378.0  37003116.0
# 225                           Yemen    962066.0  237613.0    506523.0
# 226                          Zambia  13493953.0  205990.0  12625626.0
# ...

# %% [markdown]
# ### 3. Write a Python program to get the latest number of confirmed deaths and recovered people of Novel Coronavirus (COVID-19) cases Country/Region - Province/State wise.

# %%
# Import pandas

import pandas as pd

# %%
# Read COVID 19 Dataset CSV File using pandas
df = pd.read_csv('covid_19_data.csv')

# Print File Data 
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
# Print latest number of confirmed deaths and recovered people of Novel Coronavirus (COVID-19) cases Country/Region - Province/State wise
data = df.groupby(['Country/Region', 'Province/State'])['Confirmed', 'Deaths', 'Recovered'].max()

# Display All Rows Country/Region and State Wise
pd.set_option('display.max_rows', None)

# Print
data
# Out:
# <ipython-input-21-153a199a6cc7>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data = df.groupby(['Country/Region', 'Province/State'])['Confirmed', 'Deaths', 'Recovered'].max()
#                                                              Confirmed  \
# Country/Region Province/State
# Australia      Australian Capital Territory                      124.0
#                Diamond Princess cruise ship                        0.0
#                External territories                                0.0
#                From Diamond Princess                               8.0
#                Jervis Bay Territory                                0.0
#                New South Wales                                  5585.0
#                Northern Territory                                173.0
#                Queensland                                       1618.0
# ...

# %% [markdown]
# ### 4. Write a Python program to get the Chinese province wise cases of confirmed, deaths and recovered cases of Novel Coronavirus (COVID-19).

# %%
# Import pandas

import pandas as pd

# %%
# Read COVID 19 Dataset CSV File using pandas
df = pd.read_csv('covid_19_data.csv')

# Print File Data 
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
# Get China Data
c_data = df[df['Country/Region']=='China']

# Filter Data
c_get_data = c_data[['Province/State', 'Confirmed', 'Deaths', 'Recovered']]

# Display Data
c_get_data
# Out:
#      Province/State  Confirmed  Deaths  Recovered
# 38          Unknown        0.0     0.0        0.0
# 86          Unknown        0.0     0.0        0.0
# 129         Unknown        0.0     0.0        0.0
# 175         Unknown        0.0     0.0        0.0
# 224         Unknown        0.0     0.0        0.0
# 277         Unknown        0.0     0.0        0.0
# 331         Unknown        0.0     0.0        0.0
# 387         Unknown        0.0     0.0        0.0
# 447         Unknown        0.0     0.0        0.0
# 511         Unknown        0.0     0.0        0.0
# 580         Unknown        0.0     0.0        0.0
# 649         Unknown        0.0     0.0        0.0
# 719         Unknown        0.0     0.0        0.0
# 791         Unknown        0.0     0.0        0.0
# 864         Unknown        0.0     0.0        0.0
# 937         Unknown        0.0     0.0        0.0
# 1011        Unknown        0.0     0.0        0.0
# 1085        Unknown        0.0     0.0        0.0
# ...

# %%
result = c_get_data.sort_values(by='Confirmed', ascending=False)

# Change Index Here
result = result.reset_index(drop=True)

# Print the Chinese province wise cases of confirmed, deaths and recovered cases of Novel Coronavirus (COVID-19)
result
# Out:
#    Province/State  Confirmed  Deaths  Recovered
# 0         Unknown        0.0     0.0        0.0
# 1         Unknown        0.0     0.0        0.0
# 2         Unknown        0.0     0.0        0.0
# 3         Unknown        0.0     0.0        0.0
# 4         Unknown        0.0     0.0        0.0
# 5         Unknown        0.0     0.0        0.0
# 6         Unknown        0.0     0.0        0.0
# 7         Unknown        0.0     0.0        0.0
# 8         Unknown        0.0     0.0        0.0
# 9         Unknown        0.0     0.0        0.0
# 10        Unknown        0.0     0.0        0.0
# 11        Unknown        0.0     0.0        0.0
# 12        Unknown        0.0     0.0        0.0
# 13        Unknown        0.0     0.0        0.0
# 14        Unknown        0.0     0.0        0.0
# 15        Unknown        0.0     0.0        0.0
# 16        Unknown        0.0     0.0        0.0
# 17        Unknown        0.0     0.0        0.0
# 18        Unknown        0.0     0.0        0.0
# ...

# %% [markdown]
# ###  5. Write a Python program to list countries with no cases of Novel Coronavirus (COVID-19) recovered.

# %%
# Import pandas

import pandas as pd

# %%
# Read COVID 19 Dataset CSV File using pandas
df = pd.read_csv('covid_19_data.csv')

# Print File Data 
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
# Get Data Country Wise Data
data = df.groupby('Country/Region')['Confirmed', 'Deaths', 'Recovered'].sum().reset_index()

# Applay Condition No Recovered Cases
result = data[data['Recovered']==0][['Country/Region', 'Confirmed', 'Deaths', 'Recovered']]

# Print Actual Result
result
# Out:
# <ipython-input-17-72e6cdf9ed36>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data = df.groupby('Country/Region')['Confirmed', 'Deaths', 'Recovered'].sum().reset_index()
#                      Country/Region  Confirmed  Deaths  Recovered
# 0                        Azerbaijan        1.0     0.0        0.0
# 1                   ('St. Martin',)        2.0     0.0        0.0
# 10                            Aruba       19.0     0.0        0.0
# 15                     Bahamas, The       10.0     0.0        0.0
# 37                       Cape Verde        1.0     0.0        0.0
# 38                   Cayman Islands        3.0     0.0        0.0
# 41                  Channel Islands        1.0     0.0        0.0
# 43                            China        0.0     0.0        0.0
# 51                          Curacao        2.0     0.0        0.0
# ...

# %% [markdown]
# ### 6. Write a Python program to get the top 10 countries data (Last Update, Country/Region, Confirmed, Deaths, Recovered) of Novel Coronavirus (COVID-19).

# %%
# Import pandas

import pandas as pd

# %%
# Read COVID 19 Dataset CSV File using pandas
df = pd.read_csv('covid_19_data.csv',usecols = ['Last Update', 'Country/Region', 'Confirmed', 'Deaths', 'Recovered'])

# Print File Data 
df
# Out:
#         Country/Region          Last Update  Confirmed  Deaths  Recovered
# 0       Mainland China      1/22/2020 17:00        1.0     0.0        0.0
# 1       Mainland China      1/22/2020 17:00       14.0     0.0        0.0
# 2       Mainland China      1/22/2020 17:00        6.0     0.0        0.0
# 3       Mainland China      1/22/2020 17:00        1.0     0.0        0.0
# 4       Mainland China      1/22/2020 17:00        0.0     0.0        0.0
# ...                ...                  ...        ...     ...        ...
# 306424         Ukraine  2021-05-30 04:20:55   102641.0  2335.0    95289.0
# 306425     Netherlands  2021-05-30 04:20:55    29147.0   245.0        0.0
# 306426  Mainland China  2021-05-30 04:20:55     1364.0     1.0     1324.0
# 306427         Ukraine  2021-05-30 04:20:55    87550.0  1738.0    83790.0
# 306428     Netherlands  2021-05-30 04:20:55   391559.0  4252.0        0.0
#
# [306429 rows x 5 columns]

# %%
# Get Data
result = df.groupby('Country/Region').max().sort_values(by='Confirmed', ascending=False)[:10]

# Print the top 10 countries data (Last Update, Country/Region, Confirmed, Deaths, Recovered) of Novel Coronavirus (COVID-19)
result
# Out:
#                 Last Update  Confirmed    Deaths  Recovered
# Country/Region
# France          4/6/20 9:37  5863138.0  108532.0   331686.0
# India           4/6/20 9:37  5713215.0   94030.0  5339838.0
# Turkey          4/6/20 9:37  5235978.0   47271.0  5094279.0
# UK              4/6/20 9:37  3910803.0  112385.0     4192.0
# US              4/6/20 9:37  3788713.0   63236.0  6399531.0
# Argentina       4/6/20 9:37  3732263.0   77108.0  3288467.0
# Brazil          4/6/20 9:37  3254893.0  111123.0  2895697.0
# Iran            4/6/20 9:37  2893218.0   79741.0  2425033.0
# Poland          4/6/20 9:37  2871371.0   73682.0  2636675.0
# Indonesia       4/6/20 9:37  1809926.0   50262.0  1659974.0

# %% [markdown]
# ### 7. Write a Python program to create a plot (lines) of total deaths, confirmed, recovered and active cases Country wise where deaths greater than 150.

# %%
# Import Pandas
import pandas as pd

# Import Pyplot
import matplotlib.pyplot as plt

# %%
# Read COVID 19 Dataset CSV File using pandas
df = pd.read_csv('covid_19_data.csv',usecols = ['Last Update', 'Country/Region', 'Confirmed', 'Deaths', 'Recovered'])

# Print File Data 
df
# Out:
#         Country/Region          Last Update  Confirmed  Deaths  Recovered
# 0       Mainland China      1/22/2020 17:00        1.0     0.0        0.0
# 1       Mainland China      1/22/2020 17:00       14.0     0.0        0.0
# 2       Mainland China      1/22/2020 17:00        6.0     0.0        0.0
# 3       Mainland China      1/22/2020 17:00        1.0     0.0        0.0
# 4       Mainland China      1/22/2020 17:00        0.0     0.0        0.0
# ...                ...                  ...        ...     ...        ...
# 306424         Ukraine  2021-05-30 04:20:55   102641.0  2335.0    95289.0
# 306425     Netherlands  2021-05-30 04:20:55    29147.0   245.0        0.0
# 306426  Mainland China  2021-05-30 04:20:55     1364.0     1.0     1324.0
# 306427         Ukraine  2021-05-30 04:20:55    87550.0  1738.0    83790.0
# 306428     Netherlands  2021-05-30 04:20:55   391559.0  4252.0        0.0
#
# [306429 rows x 5 columns]

# %%
# Find Active Cases
df['Active'] = df['Confirmed'] - df['Deaths'] - df['Recovered']

df['Active']
# Out:
# 0              1.0
# 1             14.0
# 2              6.0
# 3              1.0
# 4              0.0
#             ...
# 306424      5017.0
# 306425     28902.0
# 306426        39.0
# 306427      2022.0
# 306428    387307.0
# Name: Active, Length: 306429, dtype: float64

# %%
# Group By All Type Of Cases
g = df.groupby('Country/Region')['Confirmed', 'Deaths','Recovered','Active'].sum().reset_index()

r_data = g.sort_values(by='Deaths', ascending=False)

# Applay Conditions
r_data = r_data[r_data['Deaths']>150]

# Get Data
r_data
# Out:
# <ipython-input-44-eee694d82230>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   g = df.groupby('Country/Region')['Confirmed', 'Deaths','Recovered','Active'].sum().reset_index()
#     Country/Region     Confirmed       Deaths     Recovered        Active
# 214             US  6.049146e+09  123303762.0  5.033710e+08  5.422471e+09
# 27          Brazil  2.653588e+09   72624610.0  2.313677e+09  2.672859e+08
# 96           India  3.226768e+09   44424723.0  2.900590e+09  2.817535e+08
# 137         Mexico  4.604637e+08   43005509.0  3.617802e+08  5.567799e+07
# 213             UK  7.837944e+08   29171984.0  2.327572e+06  7.522948e+08
# ..             ...           ...          ...           ...           ...
# 32         Burundi  4.927220e+05        898.0  1.973080e+05  2.945160e+05
# 123     MS Zaandam  3.824000e+03        848.0  1.246000e+03  1.730000e+03
# ...

# %%
# Plot A Graph
plt.figure(figsize=(15, 5))

plt.plot(r_data['Country/Region'], r_data['Deaths'],color='red')

plt.plot(r_data['Country/Region'], r_data['Confirmed'],color='green')

plt.plot(r_data['Country/Region'], r_data['Recovered'], color='blue')

plt.plot(r_data['Country/Region'], r_data['Active'], color='black')

# Graoph Title 
plt.title('Total Deaths(>150), Confirmed, Recovered and Active Cases by Country')

# Graph Show
plt.show()

# %% [markdown]
# ###  8. Write a Python program to visualize the state/province wise combine number of confirmed, deaths, recovered, active Novel Coronavirus (COVID-19) cases in USA.

# %%
# Import Pandas
import pandas as pd

# Import Pyplot
import plotly.express as px

# %%
# Read COVID 19 Dataset CSV File using pandas
= pd.read_csv('covid_usa.csv')
# Print File Data 
df
# Out:
#         Province/State Country/Region          Last Update  Confirmed  Deaths  \
# 0                Hubei          China  2020-03-19T10:13:14      67800    3130
# 1                  NaN          Italy  2020-03-19T17:43:03      41035    3405
# 2                  NaN           Iran  2020-03-19T11:33:29      18407    1284
# 3                  NaN          Spain  2020-03-19T20:13:08      17963     830
# 4                  NaN        Germany  2020-03-19T20:13:08      15320      44
# ..                 ...            ...                  ...        ...     ...
# 309  W.P. Kuala Lumpur       Malaysia  2020-03-19T10:13:14          0       0
# 310        W.P. Labuan       Malaysia  2020-03-19T10:13:14          0       0
# 311     W.P. Putrajaya       Malaysia  2020-03-19T10:13:14          0       0
# 312            Unknown       Malaysia  2020-03-19T10:13:14          0       0
# 313                NaN          Tonga  2020-03-19T10:13:14          0       0
#
# ...

# %%
# Active Cases
df['Active'] = df['Confirmed'] - df['Deaths'] - df['Recovered']

df['Active']
# Out:
# 0       6988
# 1      33190
# 2      11413
# 3      16026
# 4      15163
#        ...
# 309        0
# 310        0
# 311        0
# 312        0
# 313        0
# Name: Active, Length: 314, dtype: int64

# %%
# Graph Plot
combine_us_data = df[df['Country/Region']=='US'].drop(['Country/Region','Latitude', 'Longitude'], axis=1)
combine_us_data = combine_us_data[combine_us_data.sum(axis = 1) > 0]
combine_us_data = combine_us_data.groupby(['Province/State'])['Confirmed', 'Deaths', 'Recovered', 'Active'].sum().reset_index()
combine_us_data = pd.melt(combine_us_data, id_vars='Province/State', value_vars=['Confirmed', 'Deaths', 'Recovered', 'Active'], value_name='Count', var_name='Case')
fig = px.bar(combine_us_data, x='Province/State', y='Count', text='Count', barmode='group', color='Case', title='USA State wise combine number of confirmed, deaths, recovered, active COVID-19 cases')

# Show Graph
fig.show()
# Out:
# <ipython-input-8-da66597b4743>:4: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ...

# %% [markdown]
# ### 9. Write a Python program to visualize Worldwide Confirmed Novel Coronavirus (COVID-19) cases over time.

# %%
# import Panadas
import pandas as pd

# Import Plotly
import plotly.express as px

# Import Plotly
import plotly.io as pio

# %%
# Read COVID 19 Dataset CSV File using pandas
df = pd.read_csv('covid_usa.csv')
# Print File Data 
df
# Out:
#         Province/State Country/Region          Last Update  Confirmed  Deaths  \
# 0                Hubei          China  2020-03-19T10:13:14      67800    3130
# 1                  NaN          Italy  2020-03-19T17:43:03      41035    3405
# 2                  NaN           Iran  2020-03-19T11:33:29      18407    1284
# 3                  NaN          Spain  2020-03-19T20:13:08      17963     830
# 4                  NaN        Germany  2020-03-19T20:13:08      15320      44
# ..                 ...            ...                  ...        ...     ...
# 309  W.P. Kuala Lumpur       Malaysia  2020-03-19T10:13:14          0       0
# 310        W.P. Labuan       Malaysia  2020-03-19T10:13:14          0       0
# 311     W.P. Putrajaya       Malaysia  2020-03-19T10:13:14          0       0
# 312            Unknown       Malaysia  2020-03-19T10:13:14          0       0
# 313                NaN          Tonga  2020-03-19T10:13:14          0       0
#
# ...

# %%
# Graph Ploated Here
grouped = covid_data.groupby('Last Update')['Last Update', 'Confirmed', 'Deaths'].sum().reset_index()
fig = px.line(grouped, x="Last Update", y="Confirmed",
             title="Worldwide Confirmed Novel Coronavirus(COVID-19) Cases Over Time")

# Graph Show Here
fig.show()
# Out:
# <ipython-input-13-967fa4f56582>:2: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ...
